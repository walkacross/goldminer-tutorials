# %%
from gm.api import *
# 可以直接提取数据，掘金终端需要打开，接口取数是通过网络请求的方式，效率一般，行情数据可通过subscribe订阅方式
# 设置token， 查看已有token ID,在用户-密钥管理里获取
set_token('f800d5397042d70c90afec4c2245742c7bac921c')

# %% [markdown]
# ## 获取交易标的的基本信息

# %%
instruments_in_SZSE = get_instruments(exchanges='SZSE', df=True)
print(instruments_in_SZSE)
# Out:
#       lower_limit  position  adj_factor  multiplier  sec_level       symbol  \
# 0           18.51         0    121.3988         1.0          1  SZSE.000001
# 1           18.36         0    151.4445         1.0          1  SZSE.000002
# 2           16.97         0      7.4454         1.0          1  SZSE.000004
# 3            4.29         0     49.2924         1.0          1  SZSE.000006
# 4            2.19         0     26.8933         1.0          1  SZSE.000008
# ...           ...       ...         ...         ...        ...          ...
# 3871         0.00         0      0.0000         1.0          1  SZSE.399994
# 3872         0.00         0      0.0000         1.0          1  SZSE.399995
# 3873         0.00         0      0.0000         1.0          1  SZSE.399996
# 3874         0.00         0      0.0000         1.0          1  SZSE.399997
# 3875         0.00         0      0.0000         1.0          1  SZSE.399998
#
# ...

# %% [markdown]
# ## 获取交易日历基本信息

# %% [markdown]
# ### get_trading_dates - 查询交易日列表

# %%
trading_dates = get_trading_dates(exchange='SZSE', start_date='2020-01-01', end_date='2021-09-13')
print(trading_dates)
# Out:
# ['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16', '2020-01-17', '2020-01-20', '2020-01-21', '2020-01-22', '2020-01-23', '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14', '2020-02-17', '2020-02-18', '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-24', '2020-02-25', '2020-02-26', '2020-02-27', '2020-02-28', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06', '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-23', '2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27', '2020-03-30', '2020-03-31', '2020-04-01', '2020-04-02', '2020-04-03', '2020-04-07', '2020-04-08', '2020-04-09', '2020-04-10', '2020-04-13', '2020-04-14', '2020-04-15', '2020-04-16', '2020-04-17', '2020-04-20', '20
# ...

# %% [markdown]
# ### get_previous_trading_date - 返回指定日期的上一个交易日

# %%
print(get_previous_trading_date(exchange='SZSE', date='2021-09-13'))
# Out:
# 2021-09-10
